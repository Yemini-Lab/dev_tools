# %%
import scipy.io
import configparser
import datetime
import gc
import json
import os
import re
from concurrent.futures import ThreadPoolExecutor
from datetime import datetime
from typing import Any, Dict
import cv2
import h5py
import numpy as np
import pandas as pd
import scipy.io
import skimage.io as skio
import typing_extensions
from dateutil import tz
from hdmf.backends.hdf5.h5_utils import H5DataIO
from hdmf.data_utils import DataChunkIterator
from ndx_multichannel_volume import CElegansSubject, OpticalChannelReferences, OpticalChannelPlus, ImagingVolume, \
    MultiChannelVolume, MultiChannelVolumeSeries, SegmentationLabels
from pynwb import NWBFile, NWBHDF5IO
from pynwb.behavior import SpatialSeries, Position, BehavioralTimeSeries, BehavioralEvents
from pynwb.ophys import ImageSegmentation, PlaneSegmentation, \
    DfOverF, RoiResponseSeries, Fluorescence
from pynwb.image import ImageSeries
from tifffile import TiffFile
from tifffile import imread
from tqdm import tqdm
import nd2reader
import nrrd
from pathlib import Path

from support_library.nwb.validation import validate
from support_library.nwb.visualizer import visualize
from support_library.nwb.fixer import fix_subject, fix_track

# %%
def iterate_over_directory(path):
    ttl = 0
    for root, dirs, files in os.walk(path):        
        for file in files:
            if ".nwb" in file and "updated" not in file:
                ttl += 1
                filepath = os.path.join(root, file)
                validation_summary = ''
                    
                with NWBHDF5IO(filepath, mode='r') as read_io:
                    nwbfile = read_io.read()

                    is_valid, validation_summary = validate_file(filepath, nwbfile)

                    if ttl in subjects_to_visualize:
                        visualize_file(filepath, nwbfile)

                if not is_valid:
                    update_file(filepath, validation_summary)
                    
                    
def validate_file(filepath=None, nwbfile=None):
    if filepath is None:
        substring = ""
    else:
        substring = f" {os.path.basename(filepath)}"
        
    if nwbfile is None:
        nwbfile = NWBHDF5IO(filepath, mode='r').read()
        
    print(f" | Validating{substring}...")
    is_valid, validation_summary = validate(nwbfile)
    print(f" | Validation {'PASSED' if is_valid else 'FAILED'}:")
    print(f" | | " + validation_summary.replace('\n', f'\n | |'))
    
    return is_valid, validation_summary

def visualize_file(filepath=None, nwbfile=None):
    if filepath is None:
        substring = ""
    else:
        substring = f" {os.path.basename(filepath)}"
        
    if nwbfile is None:
        nwbfile = NWBHDF5IO(filepath, mode='r').read()
    
    print(f" | Visualizing{substring}...")
    visualize(nwbfile)

def update_file(filepath=None, validation_summary=None):          
    with NWBHDF5IO(filepath, mode='r') as read_io:
        nwbfile = read_io.read()
        og_id = nwbfile.subject.subject_id
        og_description = nwbfile.subject.description
        
    if "Strain: not specified" in validation_summary:
        fix_subject(filepath, strain='OH15500', description=og_description.replace('[]', ''))
    
    fix_track(filepath, reference='maedeh')

# %%
path = 'E:\\0-WORK\\1-UMASSCHAN\\Data\\venkatachalam\\000981'
subjects_to_visualize = []

iterate_over_directory(path)
# Out:
# C:\Users\Kevin\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\spec\namespace.py:535: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
#  | Validating sub-20220327-h2_ses-20220327_ophys.nwb...
#  | Validation FAILED:
#  | | Subject: PASSED
#  | | Acquisitions: PASSED
#  | | .processing Modules: PASSED
#  | Validating sub-20220327-h2_ses-20220327_ophys_updated.nwb...
#  | Validation FAILED:
#  | | Subject: PASSED
#  | | Acquisitions: PASSED
#  | | .processing Modules: PASSED
#  | Validating sub-20220327-h4_ses-20220327_ophys.nwb...
#  | Validation FAILED:
#  | | Subject: PASSED
#  | | Acquisitions: PASSED
#  | | .processing Modules: PASSED
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 path = 'E:\\0-WORK\\1-UMASSCHAN\\Data\\venkatachalam\\000981'
#       2 subjects_to_visualize = []
# ----> 4 iterate_over_directory(path)
#
# Cell In[2], line 19, in iterate_over_directory(path)
#      16         visualize_file(filepath, nwbfile)
#      18 if not is_valid:
# ---> 19     update_file(filepath, validation_summary)
#
# Cell In[2], line 59, in update_file(filepath, validation_summary)
#      56 if "Strain: not specified" in validation_summary:
#      57     fix_subject(filepath, strain='OH15500', description=og_description.replace('[]', ''))
# ---> 59 fix_track(filepath, reference='maedeh')
#
# File E:\0-WORK\1-UMASSCHAN\Code\dev_tools\nwb\support_library\nwb\fixer.py:145, in fix_track(filepath, reference)
#     142                 nwbfile.set_modified()
#     144                 with NWBHDF5IO(filepath.replace('.nwb', '_updated.nwb'), mode='w') as export_io:
# --> 145                     export_io.export(src_io=read_io, nwbfile=nwbfile)
#     147 else:
#     148     print(f"Reference {reference} has not associated fix routine.")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pynwb\__init__.py:507, in NWBHDF5IO.export(self, **kwargs)
#     505 nwbfile = popargs('nwbfile', kwargs)
#     506 kwargs['container'] = nwbfile
# --> 507 super().export(**kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\backends\hdf5\h5tools.py:459, in HDF5IO.export(self, **kwargs)
#     457 if not write_args.get('link_data', True):
#     458     ckwargs['clear_cache'] = True
# --> 459 super().export(**ckwargs)
#     460 if cache_spec:
#     461     # add any namespaces from the src_io that have not yet been loaded
#     462     for namespace in src_io.manager.namespace_catalog.namespaces:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\backends\io.py:163, in HDMFIO.export(self, **kwargs)
#     160     else:
#     161         # clear only cached containers and builders where the container was modified
#     162         src_io.manager.purge_outdated()
# --> 163     bldr = src_io.manager.build(container, source=self.__source, root=True, export=True)
#     164 else:
#     165     bldr = src_io.read_builder()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\manager.py:173, in BuildManager.build(self, **kwargs)
#     169             raise ValueError("Cannot change container_source once set: '%s' %s.%s"
#     170                              % (container.name, container.__class__.__module__,
#     171                                 container.__class__.__name__))
#     172 # NOTE: if exporting, then existing cached builder will be ignored and overridden with new build result
# --> 173 result = self.__type_map.build(container, self, source=source, spec_ext=spec_ext, export=export)
#     174 self.prebuilt(container, result)
#     175 self.__active_prebuilt(result)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\manager.py:802, in TypeMap.build(self, **kwargs)
#     800 if manager is None:
#     801     manager = BuildManager(self)
# --> 802 builder = obj_mapper.build(container, manager, builder=builder, source=source, spec_ext=spec_ext, export=export)
#     804 # add additional attributes (namespace, data_type, object_id) to builder
#     805 namespace, data_type = self.get_container_ns_dt(container)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:733, in ObjectMapper.build(self, **kwargs)
#     731         builder = GroupBuilder(name, parent=parent, source=source)
#     732     self.__add_datasets(builder, self.__spec.datasets, container, manager, source, export)
# --> 733     self.__add_groups(builder, self.__spec.groups, container, manager, source, export)
#     734     self.__add_links(builder, self.__spec.links, container, manager, source, export)
#     735 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:1148, in ObjectMapper.__add_groups(self, builder, groups, container, build_manager, source, export)
#    1146 self.__add_datasets(sub_builder, spec.datasets, container, build_manager, source, export)
#    1147 self.__add_links(sub_builder, spec.links, container, build_manager, source, export)
# -> 1148 self.__add_groups(sub_builder, spec.groups, container, build_manager, source, export)
#    1149 empty = sub_builder.is_empty()
#    1150 if not empty or (empty and spec.required):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:1161, in ObjectMapper.__add_groups(self, builder, groups, container, build_manager, source, export)
#    1159 self.__check_quantity(attr_value, spec, container)
#    1160 if attr_value is not None:
# -> 1161     self.__add_containers(builder, spec, attr_value, build_manager, source, container, export)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:1219, in ObjectMapper.__add_containers(self, builder, spec, value, build_manager, source, parent_container, export)
#    1217 elif isinstance(value, list):
#    1218     for container in value:
# -> 1219         self.__add_containers(builder, spec, container, build_manager, source, parent_container, export)
#    1220 else:  # pragma: no cover
#    1221     msg = ("Received %s, expected AbstractContainer or a list of AbstractContainers."
#    1222            % value.__class__.__name__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:1181, in ObjectMapper.__add_containers(self, builder, spec, value, build_manager, source, parent_container, export)
#    1179 self.logger.debug("    Building newly instantiated %s '%s'" % (value.__class__.__name__, value.name))
#    1180 if isinstance(spec, BaseStorageSpec):
# -> 1181     new_builder = build_manager.build(value, source=source, spec_ext=spec, export=export)
#    1182 else:
#    1183     new_builder = build_manager.build(value, source=source, export=export)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\manager.py:173, in BuildManager.build(self, **kwargs)
#     169             raise ValueError("Cannot change container_source once set: '%s' %s.%s"
#     170                              % (container.name, container.__class__.__module__,
#     171                                 container.__class__.__name__))
#     172 # NOTE: if exporting, then existing cached builder will be ignored and overridden with new build result
# --> 173 result = self.__type_map.build(container, self, source=source, spec_ext=spec_ext, export=export)
#     174 self.prebuilt(container, result)
#     175 self.__active_prebuilt(result)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\manager.py:802, in TypeMap.build(self, **kwargs)
#     800 if manager is None:
#     801     manager = BuildManager(self)
# --> 802 builder = obj_mapper.build(container, manager, builder=builder, source=source, spec_ext=spec_ext, export=export)
#     804 # add additional attributes (namespace, data_type, object_id) to builder
#     805 namespace, data_type = self.get_container_ns_dt(container)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:733, in ObjectMapper.build(self, **kwargs)
#     731         builder = GroupBuilder(name, parent=parent, source=source)
#     732     self.__add_datasets(builder, self.__spec.datasets, container, manager, source, export)
# --> 733     self.__add_groups(builder, self.__spec.groups, container, manager, source, export)
#     734     self.__add_links(builder, self.__spec.links, container, manager, source, export)
#     735 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:1161, in ObjectMapper.__add_groups(self, builder, groups, container, build_manager, source, export)
#    1159 self.__check_quantity(attr_value, spec, container)
#    1160 if attr_value is not None:
# -> 1161     self.__add_containers(builder, spec, attr_value, build_manager, source, container, export)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:1219, in ObjectMapper.__add_containers(self, builder, spec, value, build_manager, source, parent_container, export)
#    1217 elif isinstance(value, list):
#    1218     for container in value:
# -> 1219         self.__add_containers(builder, spec, container, build_manager, source, parent_container, export)
#    1220 else:  # pragma: no cover
#    1221     msg = ("Received %s, expected AbstractContainer or a list of AbstractContainers."
#    1222            % value.__class__.__name__)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:1181, in ObjectMapper.__add_containers(self, builder, spec, value, build_manager, source, parent_container, export)
#    1179 self.logger.debug("    Building newly instantiated %s '%s'" % (value.__class__.__name__, value.name))
#    1180 if isinstance(spec, BaseStorageSpec):
# -> 1181     new_builder = build_manager.build(value, source=source, spec_ext=spec, export=export)
#    1182 else:
#    1183     new_builder = build_manager.build(value, source=source, export=export)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\manager.py:173, in BuildManager.build(self, **kwargs)
#     169             raise ValueError("Cannot change container_source once set: '%s' %s.%s"
#     170                              % (container.name, container.__class__.__module__,
#     171                                 container.__class__.__name__))
#     172 # NOTE: if exporting, then existing cached builder will be ignored and overridden with new build result
# --> 173 result = self.__type_map.build(container, self, source=source, spec_ext=spec_ext, export=export)
#     174 self.prebuilt(container, result)
#     175 self.__active_prebuilt(result)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\manager.py:802, in TypeMap.build(self, **kwargs)
#     800 if manager is None:
#     801     manager = BuildManager(self)
# --> 802 builder = obj_mapper.build(container, manager, builder=builder, source=source, spec_ext=spec_ext, export=export)
#     804 # add additional attributes (namespace, data_type, object_id) to builder
#     805 namespace, data_type = self.get_container_ns_dt(container)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:732, in ObjectMapper.build(self, **kwargs)
#     730 if builder is None:
#     731     builder = GroupBuilder(name, parent=parent, source=source)
# --> 732 self.__add_datasets(builder, self.__spec.datasets, container, manager, source, export)
#     733 self.__add_groups(builder, self.__spec.groups, container, manager, source, export)
#     734 self.__add_links(builder, self.__spec.links, container, manager, source, export)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:1131, in ObjectMapper.__add_datasets(self, builder, datasets, container, build_manager, source, export)
#    1126 else:
#    1127     self.logger.debug("        Adding typed dataset for spec name: %s, %s: %s, %s: %s"
#    1128                       % (repr(spec.name),
#    1129                          spec.def_key(), repr(spec.data_type_def),
#    1130                          spec.inc_key(), repr(spec.data_type_inc)))
# -> 1131     self.__add_containers(builder, spec, attr_value, build_manager, source, container, export)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:1181, in ObjectMapper.__add_containers(self, builder, spec, value, build_manager, source, parent_container, export)
#    1179 self.logger.debug("    Building newly instantiated %s '%s'" % (value.__class__.__name__, value.name))
#    1180 if isinstance(spec, BaseStorageSpec):
# -> 1181     new_builder = build_manager.build(value, source=source, spec_ext=spec, export=export)
#    1182 else:
#    1183     new_builder = build_manager.build(value, source=source, export=export)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\manager.py:173, in BuildManager.build(self, **kwargs)
#     169             raise ValueError("Cannot change container_source once set: '%s' %s.%s"
#     170                              % (container.name, container.__class__.__module__,
#     171                                 container.__class__.__name__))
#     172 # NOTE: if exporting, then existing cached builder will be ignored and overridden with new build result
# --> 173 result = self.__type_map.build(container, self, source=source, spec_ext=spec_ext, export=export)
#     174 self.prebuilt(container, result)
#     175 self.__active_prebuilt(result)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\manager.py:802, in TypeMap.build(self, **kwargs)
#     800 if manager is None:
#     801     manager = BuildManager(self)
# --> 802 builder = obj_mapper.build(container, manager, builder=builder, source=source, spec_ext=spec_ext, export=export)
#     804 # add additional attributes (namespace, data_type, object_id) to builder
#     805 namespace, data_type = self.get_container_ns_dt(container)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\utils.py:668, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     666 def func_call(*args, **kwargs):
#     667     pargs = _check_args(args, kwargs)
# --> 668     return func(args[0], **pargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:797, in ObjectMapper.build(self, **kwargs)
#     795     else:
#     796         data = container.data
# --> 797     bldr_data, dtype = self.convert_dtype(spec, data, spec_dtype=spec_dtype)
#     798 except Exception as ex:
#     799     msg = 'could not resolve dtype for %s \'%s\'' % (type(container).__name__, container.name)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:242, in ObjectMapper.convert_dtype(cls, spec, value, spec_dtype)
#     240 ret = list()
#     241 for elem in value:
# --> 242     tmp, tmp_dtype = cls.convert_dtype(spec, elem, spec_dtype)
#     243     ret.append(tmp)
#     244 ret = type(value)(ret)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\hdmf\build\objectmapper.py:212, in ObjectMapper.convert_dtype(cls, spec, value, spec_dtype)
#     210 warning_msg = None
#     211 # Numpy Array or Zarr array
# --> 212 if (isinstance(value, np.ndarray) or
#     213         (hasattr(value, 'astype') and hasattr(value, 'dtype'))):
#     214     if spec_dtype_type is _unicode:
#     215         if isinstance(value, StrDataset):
#
# KeyboardInterrupt:

# %%
"""

tp = "E:\\0-WORK\\1-UMASSCHAN\\Data\\venkatachalam\\000981\\sub-20220327-h2\\sub-20220327-h2_ses-20220327_ophys_updated.nwb"
    
with NWBHDF5IO(tp, mode='r') as read_io:
    nwbfile = read_io.read()
    print(nwbfile.processing['NeuroPAL']['TrackedNeurons'][115])

"""
