# %%
from pynwb import NWBHDF5IO
import numpy as np

filepath = 'E:\\multilab\\flavell\\sub-2022-06-14-01-SWF702_ses-20220614_behavior+image+ophys.nwb'

io = NWBHDF5IO(filepath, mode="r")
nwbfile = io.read()

# %%
nwbfile
# Out:
# root pynwb.file.NWBFile at 0x1423401049280
# Fields:
#   acquisition: {
#     CalciumImageSeries <class 'abc.MultiChannelVolumeSeries'>,
#     NeuroPALImageRaw <class 'abc.MultiChannelVolume'>
#   }
#   devices: {
#     NIR Config <class 'pynwb.device.Device'>,
#     Spinning Disk Confocal <class 'pynwb.device.Device'>
#   }
#   file_create_date: [datetime.datetime(2024, 2, 13, 16, 6, 49, 516402, tzinfo=tzoffset(None, -28800))]
#   identifier: 2022-06-14-01
#   imaging_planes: {
#     CalciumImVol <class 'abc.ImagingVolume'>,
#     NeuroPALImVol <class 'abc.ImagingVolume'>
#   }
#   institution: MIT
#   lab: Flavell Laboratory
#   processing: {
#     BF_NIR <class 'pynwb.base.ProcessingModule'>,
#     Behavior <class 'pynwb.base.ProcessingModule'>,
#     CalciumActivity <class 'pynwb.base.ProcessingModule'>,
#     NeuroPAL <class 'pynwb.base.ProcessingModule'>
#   }
#   related_publications: ['https://doi.org/10.1016/j.cell.2023.07.035']
# ...

# %%
nwbfile.processing['CalciumActivity']
# Out:
# CalciumActivity pynwb.base.ProcessingModule at 0x1423411304080
# Fields:
#   data_interfaces: {
#     CalciumSeriesSegmentation <class 'pynwb.ophys.ImageSegmentation'>,
#     NeuronIDs <class 'abc.SegmentationLabels'>,
#     SignalCalciumImResponseSeries <class 'pynwb.ophys.RoiResponseSeries'>,
#     SignalRawFluor <class 'pynwb.ophys.Fluorescence'>
#   }
#   description: Calcium time series metadata, segmentation, and fluorescence data

# %%
print(nwbfile.acquisition.keys())
nwbfile.processing['CalciumActivity']
# Out:
# dict_keys(['CalciumImageSeries', 'NeuroPALImageRaw'])
# CalciumActivity pynwb.base.ProcessingModule at 0x3064598062048
# Fields:
#   data_interfaces: {
#     CalciumSeriesSegmentation <class 'abc.MultiChannelVolumeSeries'>,
#     NeuronIDs <class 'abc.SegmentationLabels'>,
#     SegmentationVol1 <class 'pynwb.ophys.ImageSegmentation'>,
#     SignalRawFluor <class 'pynwb.ophys.Fluorescence'>
#   }
#   description: Calcium and RFP image series metadata, segmentation, and fluorescence data

# %%
# Get shape of raw fluoride signal
nwbfile.processing['CalciumActivity']['SignalRawFluor']['SignalCalciumImResponseSeries'].data.shape
# Out:
# (1646, 156)

# %%
# Get relevant neuron labels
nwbfile.processing['CalciumActivity']['NeuronIDs'].labels[:]
# Out:
# array(['unknown', 'RMED', 'ALA', 'RID', 'IL2DR', 'RIVR', 'ADLR', 'ASIR',
#        'URXR', 'URXL', 'URADL', 'IL1DL', 'URYDR', 'OLQDR', 'SAAVL',
#        'OLQDL', 'I4', 'unknown', 'ASKR', 'ASKL', 'unknown', 'URADR',
#        'AVHR', 'MI', 'RIVL', 'ASGR', 'AINL', 'I3', 'OLLR', 'URYDL',
#        'IL1DR', 'SMDVR', 'AVJR', 'ASER', 'unknown', 'unknown', 'unknown',
#        'AVDL', 'AINR', 'AWAR', 'RMER', 'RMDVR', 'RIPR', 'OLLL', 'SIBVR',
#        'unknown', 'IL1R', 'SMDVL', 'ASGL', 'RIAR', 'AWBR', 'AVBR', 'RIAL',
#        'unknown', 'AVDR', 'AVHL', 'RIML', 'unknown', 'AWAL', 'AVAR',
#        'IL2R', 'URBR', 'RIBR', 'unknown', 'RMDVL', 'AWBL', 'BAGL', 'AVER',
#        'AWCR', 'FLPR', 'unknown', 'unknown', 'NSMR', 'URBL', 'AVJL',
#        'AIZR', 'unknown', 'MCL', 'AIBR', 'I1R', 'unknown', 'IL2L',
#        'OLQVR', 'IL1L', 'AVAL', 'ASHR', 'AVEL', 'RICR', 'FLPL', 'I2R',
#        'URYVR', 'I1L', 'RICL', 'ASHL', 'NSML', 'OLQVL', 'AIBL', 'ASEL',
# ...

# %%
# Get relevant segmentation metadata
nwbfile.processing['CalciumActivity']['CalciumSeriesSegmentation']
# Out:
# CalciumSeriesSegmentation abc.MultiChannelVolumeSeries at 0x3064598057296
# Fields:
#   comments: no comments
#   conversion: 1.0
#   data: <HDF5 dataset "data": shape (1646, 288, 576, 25), type "<u2">
#   description: Tracking results based on RFP image series, each value i indicates that voxel belongs to ROI i,value 0 indicate that voxel belongs to the background
#   device: Spinning disk confocal pynwb.device.Device at 0x3064598060512
# Fields:
#   description: Nikon Eclipe Ti-U Inverted Microscope with Yokogawa CSU-X1 SoRA, 40x objective 1.3 NA
#   manufacturer: Nikon, Yokagawa
#
#   dimension: <HDF5 dataset "dimension": shape (3,), type "<i8">
#   format: raw
#   imaging_volume: CalciumImVol abc.ImagingVolume at 0x3064598060800
# Fields:
#   conversion: 1.0
#   description: Imaging volume used to acquire Calcium and RFP imaging data
#   device: Spinning disk confocal pynwb.device.Device at 0x3064598060512
# Fields:
# ...

# %%
# Get relevant neuron positions

# Entire array
# nwbfile.processing['CalciumActivity']['CalciumSeriesSegmentation'].data[:]

# Lazy load frame 1, slice 5.
print(np.shape(nwbfile.processing['CalciumActivity']['CalciumSeriesSegmentation'].data[1, :, :, 5]))
# Out:
# (288, 576)
